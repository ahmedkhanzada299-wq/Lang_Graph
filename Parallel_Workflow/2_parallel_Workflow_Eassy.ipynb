# %%
from langgraph.graph import StateGraph , START , END
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from typing import TypedDict , Annotated
from pydantic import BaseModel , Field
import operator

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(model='gpt-4o-mini')

# %% [markdown]
# Here we can make the schema (EvaluationSchema) for get the structured output from the model. feedback , score

# %%
class EvaluationSchema(BaseModel):
    feedback: str = Field(description="Detailed Feedback for teh essay")
    score: int =  Field(description="Score out of 10" , gt=0 , le=10)

# %%
structured_model = model.with_structured_output(EvaluationSchema)

# %% [markdown]
# `individual_scores: Annotated[list[int],operator.add]` In this we take a list data coming parallel from and take each input individually

# %%
class EssayState(TypedDict):
    essay: str
    language_feedback: str
    analysis_feedback: str
    clarity_feedback: str
    overall_feedback: str
    individual_scores: Annotated[list[int],operator.add]
    avg_score: float

# %%
def evaluate_language(state:EssayState):
    prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output =  structured_model.invoke(prompt)

    return {'language_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def evaluate_analysis(state: EssayState):

    prompt = f'Evaluate the depth of analysis of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'analysis_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def evaluate_thought(state: EssayState):

    prompt = f'Evaluate the clarity of thought of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'clarity_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def final_evaluation(state: EssayState):
    # Use safe access with get() to prevent KeyError
    language_fb = state.get("language_feedback", "")
    analysis_fb = state.get("analysis_feedback", "")
    clarity_fb = state.get("clarity_feedback", "")

    # Combine feedbacks
    prompt = (
        f"Based on the following feedbacks, create a summarized feedback:\n"
        f"Language feedback - {language_fb}\n"
        f"Depth of analysis feedback - {analysis_fb}\n"
        f"Clarity of thought feedback - {clarity_fb}"
    )

    overall_feedback = model.invoke(prompt).content

    # Handle missing or empty score list safely
    scores = state.get("individual_scores", [])
    avg_score = sum(scores) / len(scores) if scores else 0.0

    return {"overall_feedback": overall_feedback, "avg_score": avg_score}

# %%
graph = StateGraph(EssayState)

graph.add_node("evaluate_language", evaluate_language)
graph.add_node("evaluate_analysis", evaluate_analysis)
graph.add_node("evaluate_thought", evaluate_thought)
graph.add_node("final_evaluation", final_evaluation)

# Start triggers all evaluations in parallel
graph.add_edge(START, "evaluate_language")
graph.add_edge(START, "evaluate_analysis")
graph.add_edge(START, "evaluate_thought")

# All evaluations feed into final summary
graph.add_edge("evaluate_language", "final_evaluation")
graph.add_edge("evaluate_analysis", "final_evaluation")
graph.add_edge("evaluate_thought", "final_evaluation")

graph.add_edge("final_evaluation", END)

workflow = graph.compile()

# %%
essay = """India and AI Time

Now world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.

India have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.

In farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.

But problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.

One more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.

India must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.

If India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.

So, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India"."""

# %%
initial_state = {
    "essay": essay
}

workflow.invoke(initial_state)
# Out:
# {'essay': 'India and AI Time\n\nNow world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.\n\nIndia have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.\n\nIn farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.\n\nBut problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.\n\nOne more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.\n\nIndia must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.\n\nIf India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.\n\nSo, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India".',
#  'language_feedback': "The essay presents a clear viewpoint on India's relationship with artificial intelligence (AI) but suffers from significant language quality issues. The writing includes many grammatical mistakes, awkward phrasing, and informal language that detracts from the overall clarity and professionalism expected in an essay. For instance, phrases like 'new tech call Artificial Intel… something (AI)' and 'if no careful, India go back' are grammatically incorrect and awkwardly constructed.  Additionally, the use of colloquial expressions such as 'big big data' and 'go back' gives the essay an informal tone that is not suitable for a formal analysis. The structure of the essay is somewhat disorganized, with ideas jumping around without smooth transitions. There are also typos, such as 'engine-ear' instead of 'engineers,' which suggest a lack of proofreading. Furthermore, while the points made about AI's potential benefits and challenges for India are relevant, they could be expanded with more depth or examples to enhance the argument's quality. Overall, the essay shows potential but requires significant edits for grammar, organization, and vocabulary choices to improve clarity and effectiveness.",
#  'analysis_feedback': 'The essay presents some interesting initial ideas about the potential of AI in India, touching on both benefits and challenges. However, the depth of analysis is quite limited. The points made seem broadly acknowledged but lack detailed exploration or specific evidence to substantiate claims. For instance, while mentioning the benefits of AI in farming and healthcare is a good start, the essay does not provide statistics, examples, or specific case studies to support these assertions. Furthermore, the discussion of the challenges related to privacy and job loss is somewhat vague and simplistic. There is a need for more thorough articulation of these issues, perhaps by discussing potential solutions or examples from other countries. The language used is also quite simplistic, which undermines the sophistication of the analysis. Overall, while the essay touches on crucial issues, deeper engagement with the themes presented and stronger supporting arguments would greatly enhance its quality. \nOverall Score: 4 out of 10',
#  'clarity_feedback': "The essay attempts to address the topic of India's position and future regarding Artificial Intelligence (AI), showcasing both its potential benefits and challenges. However, the clarity of thought is compromised due to several grammatical mistakes, sentence structure issues, and a lack of coherence in the arguments presented. There are instances of informal language, such as ‘big big data’ and phrases like ‘go back’ that detract from the overall professionalism of the essay. \n\nThe writer presents relevant points, such as India’s strengths in technology and education, the benefits of AI in various sectors (agriculture, health, education), and significant challenges (accessibility, job loss, privacy concerns). However, these points could be elaborated further for depth and clarity. The argument lacks a well-structured flow, making it difficult for readers to follow the writer's line of reasoning. Technical terms like ‘AI’, while introduced, are not fully explained, assuming reader familiarity without context. \n\nMoreover, the conclusion tightly summarizes the major themes but fails to reinforce them effectively or suggest actionable points. In future drafts, more attention should be given to organizing thoughts logically, enhancing vocabulary, and refining grammar. \n\nOverall, the essay reflects an understanding of the subject but struggles with clarity and coherence, impacting its effectiveness.",
#  'overall_feedback': '**Summarized Feedback:**\n\nThe essay presents a clear viewpoint on India\'s relationship with artificial intelligence (AI), highlighting both potential benefits and challenges. However, it is marred by significant language issues, including numerous grammatical mistakes, awkward phrasing, and informal expressions that reduce professionalism. Phrases like "big big data" and "go back" contribute to an overly casual tone.\n\nThe depth of analysis is also lacking. While the essay touches on important topics such as AI\'s impact on farming and healthcare, it fails to provide sufficient details, statistics, or examples to substantiate its claims. The discussion of challenges like privacy and job loss is vague and simplistic, requiring more thorough exploration.\n\nAdditionally, the essay\'s organization is disjointed, making it difficult for readers to follow the argument. Technical terms are introduced without adequate explanation, assuming reader familiarity. The conclusion summarizes major themes but doesn’t effectively reinforce them or propose actionable insights.\n\nOverall, the essay demonstrates an understanding of the subject but needs significant improvements in grammar, organization, depth of analysis, and vocabulary to enhance clarity and effectiveness. The overall score reflects these deficiencies: **4 out of 10.**',
#  'individual_scores': [4, 4, 4],
#  'avg_score': 4.0}
